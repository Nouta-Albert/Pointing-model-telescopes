# %% [markdown]
# ## Pointing error ECAM analysis using my plate solving

# %%
import numpy as np
from astropy.io import fits
from astropy.wcs import WCS
from astropy.coordinates import SkyCoord, AltAz, EarthLocation
from astropy.time import Time
import os
import subprocess
import glob
#from astroquery.astrometry_net import AstrometryNet
from astropy.io import fits
import sys
from termcolor import colored

# %% [markdown]
# ### Platesolving the images

# %%
# Input and output directories
fits_dir = "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/"
output_dir = "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved/"
os.makedirs(output_dir, exist_ok=True)

# Pixel scale range (arcsec per pixel)
scale_low = 0.21
scale_high = 0.22  # True value is 0.215

# Get a list of FITS files in the input directory
fits_files = glob.glob(os.path.join(fits_dir, "*.fits"))

# Loop through the FITS files
for fits_path in fits_files:
    file_name = os.path.basename(fits_path)
    output_name = file_name.replace(".fits", ".solved.fits")

    # Open FITS file
    with fits.open(fits_path) as hdul:
        header = hdul[0].header
        ra_approx = header['HIERARCH OGE TEL TARG ALPHA INST']  # Fetch RA from header
        dec_approx = header['HIERARCH OGE TEL TARG DELTA INST']  # Fetch Dec from header

        try:
            # Run solve-field for each FITS file with specified parameters
            result = subprocess.run(
                [
                    "ssh", "glsastro",
                    f"cd {output_dir} &&",  # Ensure working directory
                    "solve-field",
                    #"--verbose",  # Enables verbose output (chatty)
                    "--overwrite",  # Overwrite existing output files
                    "--no-verify",  # Skips verification of FITS headers
                    #"--no-fits2fits",  # Avoid creating intermediate FITS files. Looks like this argument is deprecated.
                    f"--ra {ra_approx}",  # Approximate RA (Right Ascension)
                    f"--dec {dec_approx}",  # Approximate Dec (Declination)
                    "--scale-units", "arcsecperpix",  # Scale units
                    f"--scale-low {scale_low}",  # Minimum pixel scale
                    f"--scale-high {scale_high}",  # Maximum pixel scale
                    "--crpix-x","2121", #set the WCS reference point to the given position
                    "--crpix-y","2121.5", #set the WCS reference point to the given position
                    "--radius", "3",  # Search radius
                    "--depth", "50", #controls number of features to be considered during solving. Higher values increases accuracy but takes longer time.
                    "--objs", "100", #maximum number of objects used for solving
                    "-z 4",
                    "--no-plots",  # Suppress plot outputs
                    f"--dir {output_dir}",  # Directory for output files
                    f"--new-fits {output_name}",  # Name of the new FITS file
                    fits_path  # The FITS file to be solved
                ],
                check=True,  # Raise an exception if the command fails
                stdout=subprocess.PIPE,  # Capture stdout
                stderr=subprocess.PIPE,  # Capture stderr
                text=True  # Ensure text output
            )
            # Display output
            print(colored("*******************************************", "green"))
            print(" ")
            print(colored(f"Output for {file_name}:", "blue", attrs=["bold"]))
            print(result.stdout)  # Show standard output
            print(colored("*******************************************", "green"))
            print(colored(f"SOLVED: {file_name}", "green", attrs=["bold"]))

        except subprocess.CalledProcessError as e:
            print(colored("*******************************************", "red"))
            print(colored(f"Failed to solve: {file_name}.", "red", attrs=["bold"]))
            print(f"Error: {e.stderr}")
            print(colored("*******************************************", "red"))
            print(" ")
# Out:
# *******************************************
#
# Output for ECAM.2025-04-02T10:03:41.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T10:03:41.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 906 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T10:03:41.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (269.395,34.2848)
# Field 1 did not solve (index index-2mass-06-07.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-05-07.fits, field objects 1-50).
#   log-odds ratio 202.625 (9.97134e+87), 30 match, 0 conflict, 38 distractors, 37 index.
#   RA,Dec = (269.207,34.3837), pixel scale 0.215241 arcsec/pix.
#   Hit/miss:   Hit/miss: +++++++++++++++-+-++-+--++-+---+-----+-+---+----+--+-------+-------+(best)----------------------------++++
# Field 1: solved with index index-2mass-04-31.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T10:03:41.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T10:03:41.000.fits
# Field center: (RA,Dec) = (269.206823, 34.383729) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (17:56:49.637, +34:23:01.426).
# Field size: 15.0453 x 15.1149 arcminutes
# Field rotation angle: up is 0.157688 degrees E of N
# Field parity: pos
# Creating new FITS file "ECAM.2025-04-02T10:03:41.000.solved.fits"...
#
#
# *******************************************
# SOLVED: ECAM.2025-04-02T10:03:41.000.fits
# *******************************************
#
# Output for ECAM.2025-04-02T10:01:50.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T10:01:50.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 1420 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T10:01:50.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (266.356,21.2667)
# Field 1 did not solve (index index-2mass-06-07.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-05-07.fits, field objects 1-50).
#   log-odds ratio 188.184 (5.33714e+81), 27 match, 0 conflict, 13 distractors, 34 index.
#   RA,Dec = (266.112,21.3609), pixel scale 0.215213 arcsec/pix.
#   Hit/miss:   Hit/miss: +++++-++++-+++++++-+-++-++++++-------+-+(best)---c----------------------------------------------------++++
# Field 1: solved with index index-2mass-04-31.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T10:01:50.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T10:01:50.000.fits
# Field center: (RA,Dec) = (266.111508, 21.360882) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (17:44:26.762, +21:21:39.174).
# Field size: 15.0546 x 15.1148 arcminutes
# Field rotation angle: up is 0.133164 degrees E of N
# Field parity: pos
# Creating new FITS file "ECAM.2025-04-02T10:01:50.000.solved.fits"...
#
#
# *******************************************
# SOLVED: ECAM.2025-04-02T10:01:50.000.fits
# *******************************************
#
# Output for ECAM.2025-04-02T09:59:52.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:59:52.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 1936 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:59:52.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (264.755,8.20789)
# Field 1 did not solve (index index-2mass-06-07.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-05-07.fits, field objects 1-50).
#   log-odds ratio 144.631 (6.49278e+62), 22 match, 0 conflict, 43 distractors, 30 index.
#   RA,Dec = (264.465,8.30538), pixel scale 0.215221 arcsec/pix.
#   Hit/miss:   Hit/miss: ++-++++++--+--+++-+-+-----+--+--++---+------+-------+-----------+(best)-------------------------------++++
# Field 1: solved with index index-2mass-04-31.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:59:52.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:59:52.000.fits
# Field center: (RA,Dec) = (264.464775, 8.305375) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (17:37:51.546, +08:18:19.349).
# Field size: 15.0455 x 15.0965 arcminutes
# Field rotation angle: up is 0.113226 degrees E of N
# Field parity: pos
# Creating new FITS file "ECAM.2025-04-02T09:59:52.000.solved.fits"...
#
#
# *******************************************
# SOLVED: ECAM.2025-04-02T09:59:52.000.fits
# *******************************************
#
# Output for ECAM.2025-04-02T09:57:49.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:57:49.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 2537 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:57:49.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (264.486,-4.78003)
# Field 1 did not solve (index index-2mass-06-07.fits, field objects 1-50).
#   log-odds ratio 90.4053 (1.83035e+39), 12 match, 0 conflict, 21 distractors, 19 index.
#   RA,Dec = (264.154,-4.68377), pixel scale 0.215195 arcsec/pix.
#   Hit/miss:   Hit/miss: +++++++-++----+------+----------+(best)---------------------------------------------------------------++++
# Field 1: solved with index index-2mass-05-07.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:57:49.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:57:49.000.fits
# Field center: (RA,Dec) = (264.153825, -4.683738) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (17:36:36.918, -04:41:01.455).
# Field size: 15.0489 x 15.1083 arcminutes
# Field rotation angle: up is 0.120535 degrees E of N
# Field parity: pos
# Creating new FITS file "ECAM.2025-04-02T09:57:49.000.solved.fits"...
#
#
# *******************************************
# SOLVED: ECAM.2025-04-02T09:57:49.000.fits
# *******************************************
#
# Output for ECAM.2025-04-02T09:55:48.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:55:48.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 2650 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:55:48.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (265.772,-17.5627)
# Field 1 did not solve (index index-2mass-06-07.fits, field objects 1-50).
#   log-odds ratio 79.495 (3.34383e+34), 11 match, 0 conflict, 70 distractors, 15 index.
#   RA,Dec = (265.395,-17.4733), pixel scale 0.215108 arcsec/pix.
#   Hit/miss:   Hit/miss: ++++----+-+--+---------+---------+--------------------------+-------------------+(best)---------------++++
# Field 1: solved with index index-2mass-05-07.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:55:48.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:55:48.000.fits
# Field center: (RA,Dec) = (265.395434, -17.473228) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (17:41:34.904, -17:28:23.621).
# Field size: 15.0509 x 15.1161 arcminutes
# Field rotation angle: up is 0.127165 degrees E of N
# Field parity: pos
# Creating new FITS file "ECAM.2025-04-02T09:55:48.000.solved.fits"...
#
#
# *******************************************
# SOLVED: ECAM.2025-04-02T09:55:48.000.fits
# *******************************************
#
# Output for ECAM.2025-04-02T09:53:45.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:53:45.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 819 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:53:45.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (248.171,30.5006)
# Field 1 did not solve (index index-2mass-06-02.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-05-02.fits, field objects 1-50).
#   log-odds ratio 215.948 (6.09682e+93), 33 match, 0 conflict, 55 distractors, 38 index.
#   RA,Dec = (247.925,30.6575), pixel scale 0.21501 arcsec/pix.
#   Hit/miss:   Hit/miss: +++++-++++++++++++-+-++---++++-+--------++--------+--+-------+------++-----------------+(best)--------++++
# Field 1: solved with index index-2mass-04-10.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:53:45.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:53:45.000.fits
# Field center: (RA,Dec) = (247.924456, 30.657704) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (16:31:41.869, +30:39:27.735).
# Field size: 15.0468 x 15.1143 arcminutes
# Field rotation angle: up is 0.108755 degrees E of N
# Field parity: pos
# Creating new FITS file "ECAM.2025-04-02T09:53:45.000.solved.fits"...
#
#
# *******************************************
# SOLVED: ECAM.2025-04-02T09:53:45.000.fits
# *******************************************
#
# Output for ECAM.2025-04-02T09:51:54.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:51:54.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 1068 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:51:54.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (249.604,17.4084)
# Field 1 did not solve (index index-2mass-06-07.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-06-02.fits, field objects 1-50).
#   log-odds ratio 116.629 (4.48276e+50), 15 match, 0 conflict, 18 distractors, 21 index.
#   RA,Dec = (249.319,17.5488), pixel scale 0.215213 arcsec/pix.
#   Hit/miss:   Hit/miss: ++++++--++++-+++-+--------------+(best)---------------------------------------------------------------++++
# Field 1: solved with index index-2mass-05-07.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:51:54.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:51:54.000.fits
# Field center: (RA,Dec) = (249.319438, 17.548806) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (16:37:16.665, +17:32:55.703).
# Field size: 15.0436 x 15.1066 arcminutes
# Field rotation angle: up is 0.119744 degrees E of N
# Field parity: pos
# Creating new FITS file "ECAM.2025-04-02T09:51:54.000.solved.fits"...
#
#
# *******************************************
# SOLVED: ECAM.2025-04-02T09:51:54.000.fits
# *******************************************
#
# Output for ECAM.2025-04-02T09:50:02.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:50:02.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 1435 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:50:02.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (251.785,4.57367)
# Field 1 did not solve (index index-2mass-06-07.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-05-07.fits, field objects 1-50).
#   log-odds ratio 193.45 (1.03346e+84), 28 match, 1 conflict, 17 distractors, 36 index.
#   RA,Dec = (251.462,4.70581), pixel scale 0.215152 arcsec/pix.
#   Hit/miss:   Hit/miss: +++++++-++++++-+++++--+-++-++--+c+------++---+(best)--------------------------------------------------++++
# Field 1: solved with index index-2mass-04-29.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:50:02.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:50:02.000.fits
# Field center: (RA,Dec) = (251.462240, 4.705901) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (16:45:50.938, +04:42:21.244).
# Field size: 15.0485 x 15.1084 arcminutes
# Field rotation angle: up is 0.105305 degrees E of N
# Field parity: pos
# Creating new FITS file "ECAM.2025-04-02T09:50:02.000.solved.fits"...
#
#
# *******************************************
# SOLVED: ECAM.2025-04-02T09:50:02.000.fits
# *******************************************
#
# Output for ECAM.2025-04-02T09:48:08.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:48:08.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 1649 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:48:08.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (255.073,-7.84853)
# Field 1 did not solve (index index-2mass-06-07.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-05-07.fits, field objects 1-50).
#   log-odds ratio 164.024 (1.71722e+71), 26 match, 0 conflict, 43 distractors, 32 index.
#   RA,Dec = (254.712,-7.72881), pixel scale 0.214671 arcsec/pix.
#   Hit/miss:   Hit/miss: +-++-++++++++++-+++---++-++--+-+-----++--------------+--------------+(best)---------------------------++++
# Field 1: solved with index index-2mass-04-29.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:48:08.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:48:08.000.fits
# Field center: (RA,Dec) = (254.711423, -7.728602) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (16:58:50.742, -07:43:42.968).
# Field size: 15.0413 x 15.1034 arcminutes
# Field rotation angle: up is 0.0998489 degrees E of N
# Field parity: pos
# Creating new FITS file "ECAM.2025-04-02T09:48:08.000.solved.fits"...
#
#
# *******************************************
# SOLVED: ECAM.2025-04-02T09:48:08.000.fits
# *******************************************
#
# Output for ECAM.2025-04-02T09:46:07.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:46:07.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 2652 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:46:07.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (260.012,-19.6143)
# Field 1 did not solve (index index-2mass-06-07.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-05-07.fits, field objects 1-50).
#   log-odds ratio 144.224 (4.32196e+62), 23 match, 0 conflict, 57 distractors, 30 index.
#   RA,Dec = (259.608,-19.5132), pixel scale 0.215224 arcsec/pix.
#   Hit/miss:   Hit/miss: -++++-+++-++--+----+-+++-+-+++--+------+-------------------+---------+---------+(best)----------------++++
# Field 1: solved with index index-2mass-04-28.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:46:07.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:46:07.000.fits
# Field center: (RA,Dec) = (259.607471, -19.513175) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (17:18:25.793, -19:30:47.431).
# Field size: 15.0524 x 15.1078 arcminutes
# Field rotation angle: up is 0.126064 degrees E of N
# Field parity: pos
# Creating new FITS file "ECAM.2025-04-02T09:46:07.000.solved.fits"...
#
#
# *******************************************
# SOLVED: ECAM.2025-04-02T09:46:07.000.fits
# *******************************************
#
# Output for ECAM.2025-04-02T09:44:03.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:44:03.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 813 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:44:03.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (230.167,22.3205)
# Field 1 did not solve (index index-2mass-06-02.fits, field objects 1-50).
#   log-odds ratio 108.866 (1.90493e+47), 14 match, 0 conflict, 20 distractors, 18 index.
#   RA,Dec = (229.857,22.513), pixel scale 0.215445 arcsec/pix.
#   Hit/miss:   Hit/miss: ++++-+++++-----++------+-+-------+(best)--------------------------------------------------------------++++
# Field 1: solved with index index-2mass-05-02.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:44:03.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:44:03.000.fits
# Field center: (RA,Dec) = (229.857229, 22.513006) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (15:19:25.735, +22:30:46.823).
# Field size: 15.0459 x 15.12 arcminutes
# Field rotation angle: up is 0.0856059 degrees E of N
# Field parity: pos
# Creating new FITS file "ECAM.2025-04-02T09:44:03.000.solved.fits"...
#
#
# *******************************************
# SOLVED: ECAM.2025-04-02T09:44:03.000.fits
# *******************************************
#
# Output for ECAM.2025-04-02T09:42:12.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:42:12.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 965 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:42:12.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (235.012,10.136)
# Field 1 did not solve (index index-2mass-06-07.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-06-02.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-05-07.fits, field objects 1-50).
#   log-odds ratio 75.1046 (4.14498e+32), 10 match, 0 conflict, 23 distractors, 16 index.
#   RA,Dec = (234.683,10.3069), pixel scale 0.215345 arcsec/pix.
#   Hit/miss:   Hit/miss: +-+---+++++---+---+-------------+(best)---------------------------------------------------------------++++
# Field 1: solved with index index-2mass-05-02.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:42:12.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:42:12.000.fits
# Field center: (RA,Dec) = (234.682756, 10.306919) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (15:38:43.861, +10:18:24.908).
# Field size: 15.0518 x 15.1123 arcminutes
# Field rotation angle: up is 0.0800947 degrees E of N
# Field parity: pos
# Creating new FITS file "ECAM.2025-04-02T09:42:12.000.solved.fits"...
#
#
# *******************************************
# SOLVED: ECAM.2025-04-02T09:42:12.000.fits
# *******************************************
#
# Output for ECAM.2025-04-02T09:40:21.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:40:21.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 1015 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:40:21.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (240.353,-1.59875)
# Field 1 did not solve (index index-2mass-06-07.fits, field objects 1-50).
#   log-odds ratio 72.3466 (2.62854e+31), 9 match, 0 conflict, 15 distractors, 13 index.
#   RA,Dec = (239.994,-1.44374), pixel scale 0.215156 arcsec/pix.
#   Hit/miss:   Hit/miss: ++---++++-----++-------+(best)------------------------------------------------------------------------++++
# Field 1: solved with index index-2mass-05-07.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:40:21.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:40:21.000.fits
# Field center: (RA,Dec) = (239.993582, -1.443659) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (15:59:58.460, -01:26:37.173).
# Field size: 15.0475 x 15.0731 arcminutes
# Field rotation angle: up is 0.0531007 degrees E of N
# Field parity: pos
# Creating new FITS file "ECAM.2025-04-02T09:40:21.000.solved.fits"...
#
#
# *******************************************
# SOLVED: ECAM.2025-04-02T09:40:21.000.fits
# *******************************************
#
# Output for ECAM.2025-04-02T09:38:25.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:38:25.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 1760 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:38:25.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (246.854,-12.5754)
# Field 1 did not solve (index index-2mass-06-07.fits, field objects 1-50).
#   log-odds ratio 80.436 (8.56853e+34), 10 match, 0 conflict, 7 distractors, 14 index.
#   RA,Dec = (246.46,-12.4418), pixel scale 0.215211 arcsec/pix.
#   Hit/miss:   Hit/miss: ++-+-+++--++--+-+(best)-------------------------------------------------------------------------------++++
# Field 1: solved with index index-2mass-05-07.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:38:25.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:38:25.000.fits
# Field center: (RA,Dec) = (246.459651, -12.441742) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (16:25:50.316, -12:26:30.272).
# Field size: 15.0512 x 15.1075 arcminutes
# Field rotation angle: up is 0.103177 degrees E of N
# Field parity: pos
# Creating new FITS file "ECAM.2025-04-02T09:38:25.000.solved.fits"...
#
#
# *******************************************
# SOLVED: ECAM.2025-04-02T09:38:25.000.fits
# *******************************************
#
# Output for ECAM.2025-04-02T09:36:27.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:36:27.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 2990 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:36:27.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (255.163,-22.3643)
# Field 1 did not solve (index index-2mass-06-10.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-06-07.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-05-10.fits, field objects 1-50).
#   log-odds ratio 136.145 (1.33985e+59), 17 match, 0 conflict, 17 distractors, 21 index.
#   RA,Dec = (254.729,-22.2603), pixel scale 0.215217 arcsec/pix.
#   Hit/miss:   Hit/miss: ++++++++++++--+-++----------+----+(best)--------------------------------------------------------------++++
# Field 1: solved with index index-2mass-05-07.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:36:27.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:36:27.000.fits
# Field center: (RA,Dec) = (254.728495, -22.260331) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (16:58:54.839, -22:15:37.193).
# Field size: 15.0529 x 15.1094 arcminutes
# Field rotation angle: up is 0.138777 degrees E of N
# Field parity: pos
# Creating new FITS file "ECAM.2025-04-02T09:36:27.000.solved.fits"...
#
#
# *******************************************
# SOLVED: ECAM.2025-04-02T09:36:27.000.fits
# *******************************************
#
# Output for ECAM.2025-04-02T09:34:26.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:34:26.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 798 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:34:26.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (215.715,11.1346)
# Field 1 did not solve (index index-2mass-06-06.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-06-02.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-05-06.fits, field objects 1-50).
#   log-odds ratio 124.336 (9.96235e+53), 16 match, 0 conflict, 9 distractors, 20 index.
#   RA,Dec = (215.358,11.3439), pixel scale 0.215307 arcsec/pix.
#   Hit/miss:   Hit/miss: ++++-++-++++++--+-+----++(best)-----------------------------------------------------------------------++++
# Field 1: solved with index index-2mass-05-02.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:34:26.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:34:26.000.fits
# Field center: (RA,Dec) = (215.358325, 11.344023) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (14:21:25.998, +11:20:38.482).
# Field size: 15.0574 x 15.1023 arcminutes
# Field rotation angle: up is 0.0399583 degrees E of N
# Field parity: pos
# Creating new FITS file "ECAM.2025-04-02T09:34:26.000.solved.fits"...
#
#
# *******************************************
# SOLVED: ECAM.2025-04-02T09:34:26.000.fits
# *******************************************
#
# Output for ECAM.2025-04-02T09:32:33.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:32:33.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 923 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:32:33.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (222.901,0.34964)
# Field 1 did not solve (index index-2mass-06-10.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-06-07.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-06-06.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-06-02.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-05-10.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-05-07.fits, field objects 1-50).
#   log-odds ratio 94.4332 (1.02756e+41), 12 match, 0 conflict, 21 distractors, 16 index.
#   RA,Dec = (222.533,0.537088), pixel scale 0.215242 arcsec/pix.
#   Hit/miss:   Hit/miss: ++-++-+++-----+++------+--------+(best)---------------------------------------------------------------++++
# Field 1: solved with index index-2mass-05-06.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:32:33.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:32:33.000.fits
# Field center: (RA,Dec) = (222.532882, 0.537099) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (14:50:07.892, +00:32:13.557).
# Field size: 15.0613 x 15.1095 arcminutes
# Field rotation angle: up is 0.0473996 degrees E of N
# Field parity: pos
# Creating new FITS file "ECAM.2025-04-02T09:32:33.000.solved.fits"...
#
#
# *******************************************
# SOLVED: ECAM.2025-04-02T09:32:33.000.fits
# *******************************************
#
# Output for ECAM.2025-04-02T09:30:41.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:30:41.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 1191 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:30:41.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (230.852,-9.69781)
# Field 1 did not solve (index index-2mass-06-10.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-05-10.fits, field objects 1-50).
#   log-odds ratio 207.214 (9.81654e+89), 32 match, 0 conflict, 46 distractors, 38 index.
#   RA,Dec = (230.458,-9.53119), pixel scale 0.21534 arcsec/pix.
#   Hit/miss:   Hit/miss: +++++-++++-++++-+++-+++++++-+--++--++---+-+--------+-------------------------+(best)------c-----------++++
# Field 1: solved with index index-2mass-04-43.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T09:30:41.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:30:41.000.fits
# Field center: (RA,Dec) = (230.458252, -9.531278) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (15:21:49.981, -09:31:52.602).
# Field size: 15.049 x 15.1088 arcminutes
# Field rotation angle: up is 0.0789764 degrees E of N
# Field parity: pos
# Creating new FITS file "ECAM.2025-04-02T09:30:41.000.solved.fits"...
#
#
# *******************************************
# SOLVED: ECAM.2025-04-02T09:30:41.000.fits
# *******************************************
#
# Output for ECAM.2025-04-02T09:28:50.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T09:28:50.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 1669 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# ...
# Field size: 15.045 x 15.1021 arcminutes
# Field rotation angle: up is 0.0866848 degrees E of N
# Field parity: pos
# Creating new FITS file "ECAM.2025-04-02T07:04:48.000.solved.fits"...
#
#
# *******************************************
# SOLVED: ECAM.2025-04-02T07:04:48.000.fits
# *******************************************
#
# Output for ECAM.2025-04-02T07:02:54.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T07:02:54.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 1205 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T07:02:54.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (230.712,-16.5599)
# Field 1 did not solve (index index-2mass-06-10.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-05-10.fits, field objects 1-50).
#   log-odds ratio 180.241 (1.89588e+78), 26 match, 0 conflict, 28 distractors, 32 index.
#   RA,Dec = (230.388,-16.407), pixel scale 0.215091 arcsec/pix.
#   Hit/miss:   Hit/miss: +++++-++++++++++++--+++-+-+--+----+-------+----------+(best)------------------------------------------++++
# Field 1: solved with index index-2mass-04-43.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T07:02:54.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T07:02:54.000.fits
# Field center: (RA,Dec) = (230.387678, -16.406850) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (15:21:33.043, -16:24:24.659).
# Field size: 15.0489 x 15.113 arcminutes
# Field rotation angle: up is 0.110001 degrees E of N
# Field parity: pos
# Creating new FITS file "ECAM.2025-04-02T07:02:54.000.solved.fits"...
#
#
# *******************************************
# SOLVED: ECAM.2025-04-02T07:02:54.000.fits
# *******************************************
#
# Output for ECAM.2025-04-02T07:00:43.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T07:00:43.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 795 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T07:00:43.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (243.053,32.7593)
# Field 1 did not solve (index index-2mass-06-02.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-05-02.fits, field objects 1-50).
#   log-odds ratio 180.863 (3.52885e+78), 32 match, 2 conflict, 50 distractors, 39 index.
#   RA,Dec = (242.878,32.9006), pixel scale 0.215236 arcsec/pix.
#   Hit/miss:   Hit/miss: +++-++-++-+++-++-+--+c--++++++--++---+------+--+-++--+-+-+------c-------+----------+(best)----c-c-----++++
# Field 1: solved with index index-2mass-04-10.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T07:00:43.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T07:00:43.000.fits
# Field center: (RA,Dec) = (242.877442, 32.900597) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (16:11:30.586, +32:54:02.150).
# Field size: 15.0445 x 15.1144 arcminutes
# Field rotation angle: up is 0.16223 degrees E of N
# Field parity: pos
# Creating new FITS file "ECAM.2025-04-02T07:00:43.000.solved.fits"...
#
#
# *******************************************
# SOLVED: ECAM.2025-04-02T07:00:43.000.fits
# *******************************************
#
# Output for ECAM.2025-04-02T06:58:52.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T06:58:52.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 937 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T06:58:52.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (235.633,21.0662)
# Field 1 did not solve (index index-2mass-06-02.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-05-02.fits, field objects 1-50).
#   log-odds ratio 151.853 (8.886e+65), 23 match, 0 conflict, 42 distractors, 31 index.
#   RA,Dec = (235.399,21.2155), pixel scale 0.215024 arcsec/pix.
#   Hit/miss:   Hit/miss: +-+++++++-+++++++-+--++-+---------+-------+------+--------------+(best)-------------------------------++++
# Field 1: solved with index index-2mass-04-08.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T06:58:52.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T06:58:52.000.fits
# Field center: (RA,Dec) = (235.398718, 21.215556) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (15:41:35.692, +21:12:56.001).
# Field size: 15.0556 x 15.1062 arcminutes
# Field rotation angle: up is 0.153115 degrees E of N
# Field parity: pos
# Creating new FITS file "ECAM.2025-04-02T06:58:52.000.solved.fits"...
#
#
# *******************************************
# SOLVED: ECAM.2025-04-02T06:58:52.000.fits
# *******************************************
#
# Output for ECAM.2025-04-02T06:56:56.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T06:56:56.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 1034 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T06:56:56.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (230.203,8.84472)
# Field 1 did not solve (index index-2mass-06-02.fits, field objects 1-50).
#   log-odds ratio 90.6296 (2.2906e+39), 13 match, 1 conflict, 77 distractors, 18 index.
#   RA,Dec = (229.928,9.00776), pixel scale 0.215217 arcsec/pix.
#   Hit/miss:   Hit/miss: +++++-+-++----++---+----------------------------------c----------+------------------------+(best)-----++++
# Field 1: solved with index index-2mass-05-02.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T06:56:56.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T06:56:56.000.fits
# Field center: (RA,Dec) = (229.927640, 9.007777) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (15:19:42.634, +09:00:27.997).
# Field size: 15.054 x 15.1078 arcminutes
# Field rotation angle: up is 0.0597136 degrees E of N
# Field parity: pos
# Creating new FITS file "ECAM.2025-04-02T06:56:56.000.solved.fits"...
#
#
# *******************************************
# SOLVED: ECAM.2025-04-02T06:56:56.000.fits
# *******************************************
#
# Output for ECAM.2025-04-02T06:54:52.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T06:54:52.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 993 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T06:54:52.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (226.357,-3.71461)
# Field 1 did not solve (index index-2mass-06-10.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-06-07.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-05-10.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-05-07.fits, field objects 1-50).
#   log-odds ratio 177.889 (1.80465e+77), 28 match, 0 conflict, 68 distractors, 37 index.
#   RA,Dec = (226.048,-3.54313), pixel scale 0.215288 arcsec/pix.
#   Hit/miss:   Hit/miss: +++++-+++++++++++----+-++--++---------+-----+--+-+-+-----------------+-------------------------+(best)++++
# Field 1: solved with index index-2mass-04-43.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T06:54:52.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T06:54:52.000.fits
# Field center: (RA,Dec) = (226.047949, -3.543097) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (15:04:11.508, -03:32:35.148).
# Field size: 15.0545 x 15.1121 arcminutes
# Field rotation angle: up is 0.0698404 degrees E of N
# Field parity: pos
# Creating new FITS file "ECAM.2025-04-02T06:54:52.000.solved.fits"...
#
#
# *******************************************
# SOLVED: ECAM.2025-04-02T06:54:52.000.fits
# *******************************************
#
# Output for ECAM.2025-04-02T06:52:53.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T06:52:53.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 1009 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T06:52:53.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (223.598,-16.4795)
# Field 1 did not solve (index index-2mass-06-10.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-05-10.fits, field objects 1-50).
#   log-odds ratio 196.851 (3.09967e+85), 35 match, 0 conflict, 42 distractors, 44 index.
#   RA,Dec = (223.256,-16.3033), pixel scale 0.215171 arcsec/pix.
#   Hit/miss:   Hit/miss: +++-+-++++++++--+++++-+-++++++----+-++-++--+------------+---+-+-----------+-+(best)-------------------++++
# Field 1: solved with index index-2mass-04-43.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/solved//ECAM.2025-04-02T06:52:53.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/ECAM.2025-04-02T06:52:53.000.fits
# Field center: (RA,Dec) = (223.256189, -16.303208) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (14:53:01.485, -16:18:11.550).
# Field size: 15.0492 x 15.1062 arcminutes
# Field rotation angle: up is 0.0688231 degrees E of N
# Field parity: pos
# Creating new FITS file "ECAM.2025-04-02T06:52:53.000.solved.fits"...
#
#
# *******************************************
# SOLVED: ECAM.2025-04-02T06:52:53.000.fits

# %% [markdown]
# ### Process solved files

# %%
# Observatory location for CORALIE (example: La Silla)
obs_location = EarthLocation(lon=-70.732951945082, lat=-29.259497822801, height=2378.0)

# Step 2: Process FITS Files
def process_fits_images(output_dir):
    pointing_data = []

    for file_name in os.listdir(output_dir):
        if file_name.endswith('.solved.fits'):
            fits_path = os.path.join(output_dir, file_name)

            try:
                # Open FITS file
                with fits.open(fits_path) as hdul:
                    header = hdul[0].header
                    w = WCS(header)
                    #print('wcs: ', w) 
                    obs_time = Time(float(header.get('HIERARCH OGE TEL TARG TUNIX INST')), format = 'unix')

                    #print("Obs time: ", obs_time)

                    # Extract expected azimuth and elevation
                    az_expected = header.get('HIERARCH OGE TEL TARG AZI INST', None) % 360 #to avoid negative angles but not a problem for tpoint in principle
                    el_expected = header.get('HIERARCH OGE TEL TARG ELE INST', None)

                    # Fiber pixel coordinates
                    x_ref = 2121 #header.get('HIERARCH OGE DET PIXELREF X', None)
                    y_ref = 2121.5 #header.get('HIERARCH OGE DET PIXELREF Y', None)
                    #print("Ref pixel: ", x_ref, y_ref)

                    # Check for missing data
                    if az_expected is None or el_expected is None:
                        print(f"Missing AZIMUTH/ELEVATION in {file_name}. Skipping...")
                        continue
                    if x_ref is None or y_ref is None:
                        print(f"Missing X_ref/Y_ref in {file_name}. Skipping...")
                        continue


                    
                    #Converting the ra dec in the header to horizontal coords i.e skipping the ones mentioned in the header
                    #sky_coord = SkyCoord(
                    #    ra=header.get('RA', None), dec=header.get('DEC', None),
                    #    frame="icrs", unit="deg"
                    
                    #altaz_frame = AltAz(location=obs_location, obstime=obs_time)
                    #altaz_coord = sky_coord.transform_to(altaz_frame)

                    #az_expected = altaz_coord.az.deg #+ 180) % 360
                    #el_expected = altaz_coord.alt.deg
                    #print("az actual: ", az_actual)



                    
                    # Convert pixel coordinates to RA/Dec using WCS
                    pixel_world_coords = w.pixel_to_world(x_ref, y_ref)
                    #print(fiber_world_coords)
                    # Transform RA/Dec to Azimuth/Elevation
                    sky_coord = SkyCoord(
                        ra=pixel_world_coords.ra, dec=pixel_world_coords.dec,
                        frame="icrs", unit="deg"
                    )
                    altaz_frame = AltAz(location=obs_location, obstime=obs_time)
                    altaz_coord = sky_coord.transform_to(altaz_frame)

                    az_actual = (altaz_coord.az.deg + 180) % 360
                    el_actual = altaz_coord.alt.deg
                    #print("az actual: ", az_actual)

                    # Save data
                    pointing_data.append({
                        #'file': file_name,
                        'az_expected': az_expected,
                        'el_expected': el_expected,
                        'az_actual': az_actual,
                        'el_actual': el_actual,
                    })
            except Exception as e:
                print(f"Error processing {file_name}: {e}")

    return pointing_data

# %%
# Step 3: Generate TPoint-Compatible Data File
def create_pointing_data_file(data, pointing_file):
    try:
        with open(pointing_file, "w+") as out:
            out.write("! Pointing Data for ECAM\n")
            out.write(":NODA\n")
            out.write("-29 15 24.0\n\n")  # Latitude

            for entry in data:
                out.write(f"{entry['az_expected']} {entry['el_expected']} {entry['az_actual']} {entry['el_actual']}\n")
            
            out.write("END\n")
        print(f"Pointing data file created at {pointing_file}")
    except Exception as e:
        print(f"Error creating pointing data file: {e}")


# Step 4: Compute Pointing Model
def compute_pointing_model(data_file, output_dir, model_name):
    os.makedirs(output_dir, exist_ok=True)
    tpoint_script = os.path.join(output_dir, "TPoint.dat")
    
    try:
        with open(tpoint_script, "w+") as f:
            f.write(f"indat {data_file}\n")
            f.write("USE AN AW IA IE CA TX HZSZ2 ECES\n")
            f.write("fit\n")
            f.write("call a9\n")  # creates 9 auto plots
            f.write("spawn sleep 8\n")  # Adds a delay for plotting
            f.write(f"OUTMOD {model_name}.tp\n")
            f.write(f"GC P {model_name}.ps\n")
            f.write("end\n")

        os.chdir(output_dir)
        subprocess.run(f"tpoint < {tpoint_script}", shell=True, check=True)
        print(colored("Pointing model computed successfully.", "green"))
    except Exception as e:
        print(colored(f"Error computing pointing model: {e}", "red"))

# %%
# Example Execution
pointing_data_file = f"{fits_dir}Ecam_astrometry_pm-02-04-2025.dat"  # Replace with desired output file
# Process data
pointing_data = process_fits_images(output_dir)
# Prepare data file for TPoint analysis (no corrections applied)
create_pointing_data_file(pointing_data, pointing_data_file)
# Compute pointing model (if needed for analysis)
compute_pointing_model(pointing_data_file,fits_dir, "Ecam_pointing_model-02-04-2025")
# Out:
# Pointing data file created at /home/alberte2/Sample_docs/ECAM_images_analysis-02-04-2025/Ecam_astrometry_pm-02-04-2025.dat
# running /opt/t4/beta/src/simond/tpoint/bin/tpt / / /dev/null/ /opt/t4/beta/src/simond/tpoint/etc/tpoint/tpoint.ini
#     initialization file: /opt/t4/beta/src/simond/tpoint/etc/tpoint/tpoint.ini
#     log file: /dev/null/
#
#
#
#
#
#
#
#
#
#
#
#
#
# + - - - - - - - - - - - - - - - - - - - - +
# |                 TPOINT                  |
# |   Telescope Pointing Analysis System    |
# |              Version 5.2-1              |
# + _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ +
#
# There are 54 standard pointing terms.
# Reading procedures from file /opt/t4/beta/src/simond/tpoint/etc/tpoint/procs.dat ...
# 244 lines input.
# Reading star catalogue entries from file /opt/t4/beta/src/simond/tpoint/etc/tpoint/stars.dat ...
# 209 stars input.
#
# TPOINT ready for use:  type HELP for assistance, END to quit.
#
# * ! Pointing Data for ECAM
# :NODA
# -29 15 24.0
#
# 178.336563 26.4570599 178.37550691302692 26.34312272733092
# 174.729721 39.3129501 174.76784594124297 39.22116834468121
# 171.129288 52.1712608 171.1679374950795 52.08478313605912
# 167.552826 65.0284882 167.59448431142698 64.9460079972725
# 164.153915 77.8881226 164.207183480303 77.80970509273824
# 160.148788 27.1435204 160.18872642403437 27.02781689998456
# 156.549088 39.9985619 156.58884700610372 39.903692417822135
# 152.960724 52.8561096 153.00184197856834 52.76656922412839
# 149.357925 65.7037506 149.40431793732154 65.61840826925446
# 145.908463 78.5575027 145.9738594981946 78.47638567028497
# 141.953857 27.8228798 141.9949318128481 27.705978116304877
# 138.356537 40.6821594 138.3981606780253 40.58496117535468
# 134.734222 53.5262108 134.7789077769013 53.43436118830009
# 131.152206 66.3798676 131.20517527224376 66.29239525446987
# 127.666992 79.2283936 127.74982748482637 79.14530713270044
# 123.757301 28.4961605 123.79991380485023 28.378882899367657
# 120.140839 41.3497391 120.18534608826843 41.25115820050716
# 116.528976 54.2056999 116.57833927762493 54.11255053511577
# 112.912292 67.049263 112.97418902373067 66.9606084538864
# 109.353203 79.8905869 109.46032301365346 79.80651881664265
# 105.55632 29.1599693 105.60091389109357 29.04316064890514
# 101.906517 41.9865913 101.9544145629431 41.88735152552531
# 98.2906113 54.8634911 98.34603404206297 54.769988769554914
# 94.6516037 67.7163162 94.72377098432372 67.62759634020973
# 90.9772797 80.5334473 91.11436514397519 80.4494385987751
# 87.3484421 29.8056297 87.395233860482 29.690272807543234
# 83.6885223 42.6254311 83.74007176743976 42.52680026444696
# 80.0439835 55.5042992 80.10523662132334 55.411475386667405
# 76.3596497 68.3598175 76.44285204215709 68.27206431668182
# 72.5866699 81.1739807 72.75745760747088 81.09124169171528
# 69.1405411 30.4379292 69.19001240768193 30.325322090987676
# 65.4793091 43.2877998 65.53502698898421 43.190848742271456
# 61.7989807 56.1282883 61.866211045341174 56.03729119707379
# 58.0630798 68.9870071 58.15688551675396 68.90141993718241
# 54.1968994 81.7980499 54.402000357807424 81.71796330938358
# 50.9343109 31.0560703 50.98578447465536 30.946931089721666
# 47.2598801 43.901619 47.31860053426948 43.807565330179514
# 43.558651 56.7498093 43.63084854151822 56.66189945664473
# 39.80196 69.5895691 39.90441585514162 69.50696356224289
# 25.3319702 57.3555412 25.407281015589888 57.27116940499182
# 21.5098 70.2036667 21.619379897600993 70.12492683917179
# 14.5402603 32.2599602 14.594119451065978 32.160084482116936
# 10.8575201 45.1065407 10.91960973262519 45.01938946538169
# 7.12793016 57.9540596 7.205410745364759 57.873172084344276
# 3.76722002 70.7862625 3.880417091382469 70.71040546582942
# 359.9241499975 20.0332508 359.97315215066357 19.90376767146978
# 356.35166001 32.8667412 356.4057365072015 32.77159230753302
# 352.66449022 45.7084885 352.72661410007584 45.625616738749464
# 348.9428797 58.5519714 349.0202774925591 58.47506992851896
# 345.3651104 71.4230118 345.4782064560353 71.35138396206787
# 341.8421097 20.6379395 341.89091066955694 20.51467061336039
# 338.1744804 33.4657784 338.2281556501133 33.374498986979816
# 334.4912605 46.3082504 334.5524922346208 46.228999686934436
# 330.7754898 59.1497002 330.8508079495573 59.07608615536607
# 327.1047707 72.030632 327.21448080081734 71.9621792300724
# 323.6736183 21.2276192 323.7219343978276 21.10917358897296
# 320.0060196 34.070591 320.0583484142522 33.983346786497286
# 316.3331184 46.9142303 316.39193056265685 46.83800565995669
# 312.6504898 59.770649 312.72195088692956 59.69991954659353
# 308.9506683 72.6437683 309.05361394866793 72.5780299560734
# 305.5011215 21.8431606 305.5479996828773 21.729252562433594
# 301.8446503 34.687561 301.8948971779947 34.6038925303465
# 298.1884003 47.5226288 298.2441032517914 47.44839759597072
# 294.5209274 60.3787918 294.58704969834935 60.30992246161036
# 291.0890503 73.6207809 291.1848940505132 73.55696026195581
# 287.33725 22.4599304 287.38260609872634 22.3488858652081
# 283.686005 35.322731 283.7337497798286 35.241385894038366
# 280.054565 48.1499596 280.10639813168655 48.076843407110665
# 272.765991 73.9039536 272.8492237282803 73.84038424178895
# 269.169983 23.1027508 269.21379255310933 22.9935374792687
# 265.542755 35.9457207 265.587903887952 35.86493973362486
# 261.925995 48.7910118 261.9739895430806 48.71756008080714
# 258.31723 61.6511116 258.3715069457867 61.58252386202751
# 254.686676 74.5562973 254.75893989444285 74.49212346461921
# 251.013794 23.7437 251.0563850336972 23.635567965718938
# 247.396454 36.59552 247.43946357768812 36.51440272982967
# 243.798843 49.4465904 243.8433119604235 49.37216182011821
# 240.207687 62.3157196 240.25631446460096 62.24573938363734
# 236.621185 75.2079773 236.68321558798243 75.14232619693112
# 232.851364 24.4081306 232.8925521654782 24.299886767461086
# 229.22995 37.2734184 229.27048319201478 37.19105248806421
# 225.62915 50.1352501 225.67032341602422 50.058882367291275
# 222.059341 62.9978104 222.1029415588285 62.92569184033567
# 218.534546 75.8720093 218.58710482296655 75.80401926755953
# 214.681335 25.0868397 214.72104985808113 24.977701456223794
# 211.087662 37.9403915 211.12672369084208 37.855613124540575
# 207.503937 50.8025093 207.54273355693175 50.72329412731545
# 203.95433 63.6669617 203.99477916832336 63.59172540561211
# 200.330276 76.5488815 200.37797506180664 76.47765899485492
# 196.511276 25.7695999 196.5506443813706 25.65857321758845
# 192.894882 38.6300201 192.93305963236693 38.54200513969724
# 189.264328 51.4942207 189.3024369761622 51.41155057699604
# 185.759689 64.3514175 185.79938711243298 64.2727148221553
# 181.006256 77.2209625 181.0547886258601 77.14619842849544
# END
# * *
#        coeff       change     value    sigma
#
#   1     AN         +5.504     +5.50    0.440
#   2     AW        +42.486    +42.49    0.443
#   3     IA        +95.349    +95.35    1.630
#   4     IE       +134.131   +134.13    0.660
#   5     CA        +60.119    +60.12    1.052
#   6     TX       -112.344   -112.34    0.635
#   7     HZSZ2     +20.335    +20.33    2.011
#   8     ECES     +119.374   +119.37    0.878
#
# Sky RMS =   3.77
# Popn SD =   3.95
#
# Action was taken to correct ill-conditioning.  The
# current FITTOL tolerance is 0.01, which exceeds
# the value 0.0077 encountered during the fit.
#
# * * * * *
#
# * END OF SESSION *
#
#
# Pointing model computed successfully.

# %% [markdown]
# ### Other important things to include in the above script are plots of the pointing error in az and ele vs date, the pointing infomation as I did for the other ones, polar plots of the grid and possibly other important points.
