# %% [markdown]
# ## Pointing error CORALIE analysis using plate solving

# %%
import numpy as np
from astropy.io import fits
from astropy.wcs import WCS
from astropy.coordinates import SkyCoord, AltAz, EarthLocation
from astropy.time import Time
import os
import subprocess
import glob
#from astroquery.astrometry_net import AstrometryNet
from astropy.io import fits
import sys
from termcolor import colored

# %% [markdown]
# ### Platesolving the images

# %%
# Input and output directories
#fits_dir = "/home/alberte2/Sample_docs/Pm_Coralie_2024-12-11/"
#output_dir = "/home/alberte2/Sample_docs/Pm_Coralie_2024-12-11/solved/"
fits_dir = "/home/alberte2/Sample_docs/Archives_CORALIE/"
output_dir = "/home/alberte2/Sample_docs/Archives_CORALIE/solved/"
os.makedirs(output_dir, exist_ok=True)

# Pixel scale range (arcsec per pixel)
scale_low = 0.24
scale_high = 0.28  # True value is 0.2575

# Get a list of FITS files in the input directory
fits_files = glob.glob(os.path.join(fits_dir, "*.fits"))

# Loop through the FITS files
for fits_path in fits_files:
    file_name = os.path.basename(fits_path)
    output_name = file_name.replace(".fits", ".solved.fits")

    # Open FITS file
    with fits.open(fits_path) as hdul:
        header = hdul[0].header
        ra_approx = header['HIERARCH ESO TEL TARG ALPHA INST']  # Fetch RA from header
        dec_approx = header['HIERARCH ESO TEL TARG DELTA INST']  # Fetch Dec from header

        try:
            # Run solve-field for each FITS file with specified parameters
            result = subprocess.run(
                [
                    "ssh", "glsastro",
                    "cd /home/alberte2/Sample_docs/Archives_CORALIE/ &&", 
                    #"cd /home/alberte2/Sample_docs/Pm_Coralie_2024-12-11/solved/ &&",  # Ensure working directory
                    "solve-field",
                    #"--verbose",  # Enables verbose output (chatty)
                    "--overwrite",  # Overwrite existing output files
                    "--no-verify",  # Skips verification of FITS headers
                    #"--no-fits2fits",  # Avoid creating intermediate FITS files
                    f"--ra {ra_approx}",  # Approximate RA (Right Ascension)
                    f"--dec {dec_approx}",  # Approximate Dec (Declination)
                    "--scale-units", "arcsecperpix",  # Scale units
                    f"--scale-low {scale_low}",  # Minimum pixel scale
                    f"--scale-high {scale_high}",  # Maximum pixel scale
                    "--radius", "3",  # Search radius
                    "--depth", "50", #controls number of features to be considered during solving. Higher values increases accuracy but takes longer time.
                    "--objs", "100", #maximum number of objects used for solving
                    "-z 4",
                    "--no-plots",  # Suppress plot outputs
                    f"--dir {output_dir}",  # Directory for output files
                    f"--new-fits {output_name}",  # Name of the new FITS file
                    fits_path  # The FITS file to be solved
                ],
                check=True,  # Raise an exception if the command fails
                stdout=subprocess.PIPE,  # Capture stdout
                stderr=subprocess.PIPE,  # Capture stderr
                text=True  # Ensure text output
            )
            # Display output
            print(colored("*******************************************", "green"))
            print(" ")
            print(colored(f"Output for {file_name}:", "blue", attrs=["bold"]))
            print(result.stdout)  # Show standard output
            print(colored("*******************************************", "green"))
            print(colored(f"SOLVED: {file_name}", "green", attrs=["bold"]))

        except subprocess.CalledProcessError as e:
            print(colored("*******************************************", "red"))
            print(colored(f"Failed to solve: {file_name}.", "red", attrs=["bold"]))
            print(f"Error: {e.stderr}")
            print(colored("*******************************************", "red"))
            print(" ")
# Out:
# *******************************************
#
# Output for PCORALIE.2025-01-04T08:48:11.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/Archives_CORALIE/PCORALIE.2025-01-04T08:48:11.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 10 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/Archives_CORALIE/solved//PCORALIE.2025-01-04T08:48:11.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (185.902,-68.4413)
# Field 1 did not solve (index index-2mass-03-40.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-03-36.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-02-40.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-02-36.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-01-40.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-01-36.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-00-40.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-00-36.fits, field objects 1-50).
# Field: /home/alberte2/Sample_docs/Archives_CORALIE/PCORALIE.2025-01-04T08:48:11.000.fits
# Did not solve (or no WCS file was written).
#
#
# *******************************************
# SOLVED: PCORALIE.2025-01-04T08:48:11.000.fits
# *******************************************
#
# Output for PCORALIE.2025-01-04T08:40:58.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/Archives_CORALIE/PCORALIE.2025-01-04T08:40:58.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 97 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/Archives_CORALIE/solved//PCORALIE.2025-01-04T08:40:58.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (152.787,-58.3059)
# Field 1 did not solve (index index-2mass-03-38.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-03-36.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-02-38.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-02-36.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-01-38.fits, field objects 1-50).
#   log-odds ratio 97.9034 (3.30282e+42), 25 match, 0 conflict, 40 distractors, 39 index.
#   RA,Dec = (152.573,-58.1833), pixel scale 0.261462 arcsec/pix.
#   Hit/miss:   Hit/miss: +++++++++-++-+++-+-++++---++-------------+------+-------+-------+(best)----------------------------++++
# Field 1: solved with index index-2mass-01-36.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/Archives_CORALIE/solved//PCORALIE.2025-01-04T08:40:58.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/Archives_CORALIE/PCORALIE.2025-01-04T08:40:58.000.fits
# Field center: (RA,Dec) = (152.572413, -58.183329) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (10:10:17.379, -58:10:59.986).
# Field size: 5.60284 x 4.48062 arcminutes
# Field rotation angle: up is -70.5528 degrees E of N
# Field parity: pos
# Creating new FITS file "PCORALIE.2025-01-04T08:40:58.000.solved.fits"...
#
#
# *******************************************
# SOLVED: PCORALIE.2025-01-04T08:40:58.000.fits
# *******************************************
#
# Output for PCORALIE.2025-01-04T08:38:04.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/Archives_CORALIE/PCORALIE.2025-01-04T08:38:04.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 18 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/Archives_CORALIE/solved//PCORALIE.2025-01-04T08:38:04.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (151.768,-52.3063)
# Field 1 did not solve (index index-2mass-03-38.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-03-36.fits, field objects 1-50).
#   log-odds ratio 24.9287 (6.70475e+10), 5 match, 0 conflict, 9 distractors, 14 index.
#   RA,Dec = (151.535,-52.1848), pixel scale 0.262355 arcsec/pix.
#   Hit/miss:   Hit/miss: ++--+----+---+(best)++++
# Field 1: solved with index index-2mass-02-38.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/Archives_CORALIE/solved//PCORALIE.2025-01-04T08:38:04.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/Archives_CORALIE/PCORALIE.2025-01-04T08:38:04.000.fits
# Field center: (RA,Dec) = (151.534698, -52.184913) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (10:06:08.328, -52:11:05.685).
# Field size: 5.58596 x 4.47591 arcminutes
# Field rotation angle: up is -65.4936 degrees E of N
# Field parity: pos
# Creating new FITS file "PCORALIE.2025-01-04T08:38:04.000.solved.fits"...
#
#
# *******************************************
# SOLVED: PCORALIE.2025-01-04T08:38:04.000.fits
# *******************************************
#
# Output for PCORALIE.2025-01-04T08:31:56.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/Archives_CORALIE/PCORALIE.2025-01-04T08:31:56.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 30 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/Archives_CORALIE/solved//PCORALIE.2025-01-04T08:31:56.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (137.273,-51.5347)
# Field 1 did not solve (index index-2mass-03-36.fits, field objects 1-50).
#   log-odds ratio 56.2252 (2.6199e+24), 10 match, 0 conflict, 11 distractors, 16 index.
#   RA,Dec = (137.073,-51.4345), pixel scale 0.261632 arcsec/pix.
#   Hit/miss:   Hit/miss: +++++++-+-----+-----+(best)-----++++
# Field 1: solved with index index-2mass-02-36.fits.
# Field 1 solved: writing to file /home/alberte2/Sample_docs/Archives_CORALIE/solved//PCORALIE.2025-01-04T08:31:56.000.solved to indicate this.
# Field: /home/alberte2/Sample_docs/Archives_CORALIE/PCORALIE.2025-01-04T08:31:56.000.fits
# Field center: (RA,Dec) = (137.073107, -51.434690) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (09:08:17.546, -51:26:04.883).
# Field size: 5.59123 x 4.4649 arcminutes
# Field rotation angle: up is -41.7138 degrees E of N
# Field parity: pos
# Creating new FITS file "PCORALIE.2025-01-04T08:31:56.000.solved.fits"...
#
#
# *******************************************
# SOLVED: PCORALIE.2025-01-04T08:31:56.000.fits
# *******************************************
#
# Output for PCORALIE.2025-01-04T08:29:17.000.fits:
# Reading input file 1 of 1: "/home/alberte2/Sample_docs/Archives_CORALIE/PCORALIE.2025-01-04T08:29:17.000.fits"...
# Extracting sources...
# Downsampling by 4...
# simplexy: found 14 sources.
# Solving...
# Failed to add index "/usr/share/astrometry/index-tycho2-19.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-18.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-17.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-16.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-15.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-14.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-13.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-12.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-11.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-10.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-09.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-08.bigendian.fits".
# Failed to add index "/usr/share/astrometry/index-tycho2-07.bigendian.fits".
# Reading file "/home/alberte2/Sample_docs/Archives_CORALIE/solved//PCORALIE.2025-01-04T08:29:17.000.axy"...
# Only searching for solutions within 3 degrees of RA,Dec (135.086,-28.9016)
# Field 1 did not solve (index index-2mass-03-39.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-02-39.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-01-39.fits, field objects 1-50).
# Field 1 did not solve (index index-2mass-00-39.fits, field objects 1-50).
# Field: /home/alberte2/Sample_docs/Archives_CORALIE/PCORALIE.2025-01-04T08:29:17.000.fits
# Did not solve (or no WCS file was written).
#
#
# *******************************************
# SOLVED: PCORALIE.2025-01-04T08:29:17.000.fits

# %% [raw]
# ### Plate solve using astroquery (online)

# %%
# Set up Astrometry.net client
ast = AstrometryNet()
ast.api_key = 'assceldzujfiebeh'  # Replace with your API key

# Input and output directories
fits_dir = "/home/alberte2/Sample_docs/Pm_Coralie_2024-12-11/"
output_dir = "/home/alberte2/Sample_docs/Pm_Coralie_2024-12-11/solved/"
os.makedirs(output_dir, exist_ok=True)

# Get a list of FITS files in the input directory
fits_files = glob.glob(os.path.join(fits_dir, "*.fits"))

# Loop through the FITS files
for fits_path in fits_files:
    file_name = os.path.basename(fits_path)
    output_file = os.path.join(output_dir, file_name.replace(".fits", "_solved.fits"))

    # Skip if already solved
    if os.path.exists(output_file):
        print(f"File {output_file} already solved. Skipping...")
        continue

    # Open FITS file to check headers (optional)
    try:
        with fits.open(fits_path) as hdul:
            #header = hdul[0].header
            print(f"Processing file: {file_name}")
            #print("Header information (optional):")
            #print(header)
    except Exception as e:
        print(f"Error reading FITS file {file_name}: {e}")
        continue

    # Upload FITS file for plate-solving
    try:
        print(f"Uploading {file_name} to Astrometry.net...")
        submission_id = ast.submit_from_path(fits_path)
        print("Submission ID:", submission_id)

        # Wait for the solution
        result = ast.monitor_submission(submission_id, solve_timeout=300)
        print(f"Plate-solving complete for {file_name}!")

        # Save the solved file
        if 'wcs_file' in result:
            wcs_file = result['wcs_file']
            with open(output_file, 'wb') as f:
                f.write(wcs_file)
            print(f"Solved file saved to: {output_file}")
        else:
            print(f"No WCS file returned for {file_name}.")
    except Exception as e:
        print(f"Plate-solving failed for {file_name}: {e}")
# Out:
# Processing file: PCoralie0_HD65277.fits
# Uploading PCoralie0_HD65277.fits to Astrometry.net...
# Plate-solving failed for PCoralie0_HD65277.fits: 'AstrometryNetClass' object has no attribute 'submit_from_path'
# Processing file: PCoralie1_HD78663.fits
# Uploading PCoralie1_HD78663.fits to Astrometry.net...
# Plate-solving failed for PCoralie1_HD78663.fits: 'AstrometryNetClass' object has no attribute 'submit_from_path'
# Processing file: PCoralie2_HD65243.fits
# Uploading PCoralie2_HD65243.fits to Astrometry.net...
# Plate-solving failed for PCoralie2_HD65243.fits: 'AstrometryNetClass' object has no attribute 'submit_from_path'
# Processing file: PCoralie3_HD76849.fits
# Uploading PCoralie3_HD76849.fits to Astrometry.net...
# Plate-solving failed for PCoralie3_HD76849.fits: 'AstrometryNetClass' object has no attribute 'submit_from_path'
# Processing file: PCoralie4_HD82943.fits
# Uploading PCoralie4_HD82943.fits to Astrometry.net...
# Plate-solving failed for PCoralie4_HD82943.fits: 'AstrometryNetClass' object has no attribute 'submit_from_path'
# Processing file: PCoralie5_HD93277.fits
# Uploading PCoralie5_HD93277.fits to Astrometry.net...
# Plate-solving failed for PCoralie5_HD93277.fits: 'AstrometryNetClass' object has no attribute 'submit_from_path'
# Processing file: PCoralie6_HD101563.fits
# Uploading PCoralie6_HD101563.fits to Astrometry.net...
# Plate-solving failed for PCoralie6_HD101563.fits: 'AstrometryNetClass' object has no attribute 'submit_from_path'
# Processing file: PCoralie7_HD74576.fits
# Uploading PCoralie7_HD74576.fits to Astrometry.net...
# Plate-solving failed for PCoralie7_HD74576.fits: 'AstrometryNetClass' object has no attribute 'submit_from_path'
# Processing file: PCoralie8_HD82516.fits
# Uploading PCoralie8_HD82516.fits to Astrometry.net...
# Plate-solving failed for PCoralie8_HD82516.fits: 'AstrometryNetClass' object has no attribute 'submit_from_path'
# Processing file: PCoralie9_HD86140.fits
# Uploading PCoralie9_HD86140.fits to Astrometry.net...
# Plate-solving failed for PCoralie9_HD86140.fits: 'AstrometryNetClass' object has no attribute 'submit_from_path'
# Processing file: PCoralie10_HD81639.fits
# Uploading PCoralie10_HD81639.fits to Astrometry.net...
# Plate-solving failed for PCoralie10_HD81639.fits: 'AstrometryNetClass' object has no attribute 'submit_from_path'
# Processing file: PCoralie11_HD113283.fits
# Uploading PCoralie11_HD113283.fits to Astrometry.net...
# Plate-solving failed for PCoralie11_HD113283.fits: 'AstrometryNetClass' object has no attribute 'submit_from_path'
# Processing file: PCoralie12_HD46569.fits
# Uploading PCoralie12_HD46569.fits to Astrometry.net...
# Plate-solving failed for PCoralie12_HD46569.fits: 'AstrometryNetClass' object has no attribute 'submit_from_path'
# Processing file: PCoralie13_HIP24157.fits
# Uploading PCoralie13_HIP24157.fits to Astrometry.net...
# Plate-solving failed for PCoralie13_HIP24157.fits: 'AstrometryNetClass' object has no attribute 'submit_from_path'
# Processing file: PCoralie14_HD26354.fits
# Uploading PCoralie14_HD26354.fits to Astrometry.net...
# Plate-solving failed for PCoralie14_HD26354.fits: 'AstrometryNetClass' object has no attribute 'submit_from_path'
# Processing file: PCoralie15_HD18809.fits
# Uploading PCoralie15_HD18809.fits to Astrometry.net...
# Plate-solving failed for PCoralie15_HD18809.fits: 'AstrometryNetClass' object has no attribute 'submit_from_path'
# Processing file: PCoralie16_HD40887B.fits
# Uploading PCoralie16_HD40887B.fits to Astrometry.net...
# Plate-solving failed for PCoralie16_HD40887B.fits: 'AstrometryNetClass' object has no attribute 'submit_from_path'
# Processing file: PCoralie17_HD36516.fits
# Uploading PCoralie17_HD36516.fits to Astrometry.net...
# Plate-solving failed for PCoralie17_HD36516.fits: 'AstrometryNetClass' object has no attribute 'submit_from_path'
# Processing file: PCoralie18_HD30606.fits
# Uploading PCoralie18_HD30606.fits to Astrometry.net...
# Plate-solving failed for PCoralie18_HD30606.fits: 'AstrometryNetClass' object has no attribute 'submit_from_path'
# Processing file: PCoralie19_HD30562.fits
# Uploading PCoralie19_HD30562.fits to Astrometry.net...
# Plate-solving failed for PCoralie19_HD30562.fits: 'AstrometryNetClass' object has no attribute 'submit_from_path'
# Processing file: PCoralie20_HD32564.fits
# Uploading PCoralie20_HD32564.fits to Astrometry.net...
# Plate-solving failed for PCoralie20_HD32564.fits: 'AstrometryNetClass' object has no attribute 'submit_from_path'
# Processing file: PCoralie21_HD50255.fits
# Uploading PCoralie21_HD50255.fits to Astrometry.net...
# Plate-solving failed for PCoralie21_HD50255.fits: 'AstrometryNetClass' object has no attribute 'submit_from_path'
# Processing file: PCoralie22_HD49503A.fits
# Uploading PCoralie22_HD49503A.fits to Astrometry.net...
# Plate-solving failed for PCoralie22_HD49503A.fits: 'AstrometryNetClass' object has no attribute 'submit_from_path'
# Processing file: PCoralie23_HD57678.fits
# Uploading PCoralie23_HD57678.fits to Astrometry.net...
# Plate-solving failed for PCoralie23_HD57678.fits: 'AstrometryNetClass' object has no attribute 'submit_from_path'

# %% [markdown]
# ### Process solved files

# %%
# Observatory location for CORALIE (example: La Silla)
obs_location = EarthLocation(lon=-70.732951945082, lat=-29.259497822801, height=2378.0)

# Step 2: Process FITS Files
def process_fits_images(output_dir):
    pointing_data = []

    for file_name in os.listdir(output_dir):
        if file_name.endswith('.solved.fits'):
            fits_path = os.path.join(output_dir, file_name)

            try:
                # Open FITS file
                with fits.open(fits_path) as hdul:
                    header = hdul[0].header
                    w = WCS(header)
                    #print('wcs: ', w) 
                    obs_time = Time(float(header.get('HIERARCH ESO TEL TARG TUNIX INST')), format = 'unix')

                    #print("Obs time: ", obs_time)

                    # Extract expected azimuth and elevation
                    az_expected = header.get('HIERARCH ESO TEL TARG AZI INST', None) % 360
                    el_expected = header.get('HIERARCH ESO TEL TARG ELE INST', None)

                    # Fiber pixel coordinates
                    fiber_x = header.get('HIERARCH FIBER XREFCUR', None)
                    fiber_y = header.get('HIERARCH FIBER YREFCUR', None)

                    # Check for missing data
                    if az_expected is None or el_expected is None:
                        print(f"Missing AZIMUTH/ELEVATIO in {file_name}. Skipping...")
                        continue
                    if fiber_x is None or fiber_y is None:
                        print(f"Missing FIBER_X/FIBER_Y in {file_name}. Skipping...")
                        continue

                    # Convert fiber coordinates to RA/Dec using WCS
                    fiber_world_coords = w.pixel_to_world(fiber_x, fiber_y)
                    #print(fiber_world_coords)
                    # Transform RA/Dec to Azimuth/Elevation
                    sky_coord = SkyCoord(
                        ra=fiber_world_coords.ra, dec=fiber_world_coords.dec,
                        frame="icrs", unit="deg"
                    )
                    altaz_frame = AltAz(location=obs_location, obstime=obs_time)
                    altaz_coord = sky_coord.transform_to(altaz_frame)

                    az_actual = (altaz_coord.az.deg + 180) % 360
                    el_actual = altaz_coord.alt.deg
                    #print("az actual: ", az_actual)

                    # Save data
                    pointing_data.append({
                        #'file': file_name,
                        'az_expected': az_expected,
                        'el_expected': el_expected,
                        'az_actual': az_actual,
                        'el_actual': el_actual,
                    })
            except Exception as e:
                print(f"Error processing {file_name}: {e}")

    return pointing_data

# %%
def create_pointing_data_file(data, output_file):
    try:
        with open(output_file, "w+") as out:
            out.write("! Pointing Data for CORALIE\n")
            out.write(":NODA\n")
            out.write("-29 15 24.0\n\n")  # Latitude

            for entry in data:
                out.write(f"{entry['az_expected']} {entry['el_expected']} {entry['az_actual']} {entry['el_actual']}\n")
            
            out.write("END\n")
        print(f"Pointing data file created at {output_file}")
    except Exception as e:
        print(f"Error creating pointing data file: {e}")
#for trouble shooting. not normally incuded in the script
output_file = "/home/alberte2/Sample_docs/Archives_CORALIE/test_cor.dat"  # Replace with desired output file
#output_dir = "/home/alberte2/Sample_docs/Pm_Coralie_2024-12-11/"  # Replace with desired TPoint output directory

# Process data
pointing_data = process_fits_images(output_dir)
# Prepare data file for TPoint analysis (no corrections applied)
create_pointing_data_file(pointing_data, output_file)
# Out:
# Pointing data file created at /home/alberte2/Sample_docs/Archives_CORALIE/test_cor.dat

# %%
# Step 3: Generate TPoint-Compatible Data File
def create_pointing_data_file(data, output_file):
    try:
        with open(output_file, "w+") as out:
            out.write("! Pointing Data for CORALIE\n")
            out.write(":NODA\n")
            out.write("-29 15 24.0\n\n")  # Latitude

            for entry in data:
                out.write(f"{entry['az_expected']} {entry['el_expected']} {entry['az_actual']} {entry['el_actual']}\n")
            
            out.write("END\n")
        print(f"Pointing data file created at {output_file}")
    except Exception as e:
        print(f"Error creating pointing data file: {e}")


# Step 4: Compute Pointing Model
def compute_pointing_model(data_file, output_dir, model_name):
    os.makedirs(output_dir, exist_ok=True)
    tpoint_script = os.path.join(output_dir, "TPoint.dat")
    
    try:
        with open(tpoint_script, "w+") as f:
            f.write(f"indat {data_file}\n")
            f.write("USE AN AW IA IE CA TF PZZ3 PZZ5 HZCZ4\n")
            f.write("fit\n")
            f.write("call a9\n")  # creates 9 auto plots
            f.write("spawn sleep 8\n")  # Adds a delay for plotting
            f.write(f"OUTMOD {model_name}.tp\n")
            f.write(f"GC P {model_name}.ps\n")
            f.write("end\n")

        os.chdir(output_dir)
        subprocess.run(f"tpoint < {tpoint_script}", shell=True, check=True)
        print(colored("Pointing model computed successfully.", "green"))
    except Exception as e:
        print(colored(f"Error computing pointing model: {e}", "red"))

# %%
# Example Execution
#fits_dir = "/home/alberte2/Sample_docs/Pm_Coralie_2024-12-11/"  # Replace with actual path
output_file = "/home/alberte2/Sample_docs/Pm_Coralie_2024-12-11/coralie_astrometry_pm-17-01-2025.dat"  # Replace with desired output file
#output_dir = "/home/alberte2/Sample_docs/Pm_Coralie_2024-12-11/"  # Replace with desired TPoint output directory

# Process data
pointing_data = process_fits_images(output_dir)

# Prepare data file for TPoint analysis (no corrections applied)
create_pointing_data_file(pointing_data, output_file)

# Compute pointing model (if needed for analysis)
compute_pointing_model(output_file,fits_dir, "coralie_pointing_model-17-01-2025")
# Out:
# Pointing data file created at /home/alberte2/Sample_docs/Pm_Coralie_2024-12-11/coralie_astrometry_pm-17-01-2025.dat
# running /opt/t4/beta/src/simond/tpoint/bin/tpt / / /dev/null/ /opt/t4/beta/src/simond/tpoint/etc/tpoint/tpoint.ini
#     initialization file: /opt/t4/beta/src/simond/tpoint/etc/tpoint/tpoint.ini
#     log file: /dev/null/
#
#
#
#
#
#
#
#
#
#
#
#
#
# + - - - - - - - - - - - - - - - - - - - - +
# |                 TPOINT                  |
# |   Telescope Pointing Analysis System    |
# |              Version 5.2-1              |
# + _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ +
#
# There are 54 standard pointing terms.
# Reading procedures from file /opt/t4/beta/src/simond/tpoint/etc/tpoint/procs.dat ...
# 244 lines input.
# Reading star catalogue entries from file /opt/t4/beta/src/simond/tpoint/etc/tpoint/stars.dat ...
# 209 stars input.
#
# TPOINT ready for use:  type HELP for assistance, END to quit.
#
# * ! Pointing Data for CORALIE
# :NODA
# -29 15 24.0
#
# 205.59162 59.10984 205.59024436012479 59.033174212182956
# 230.89965 49.07455 230.9086347667445 48.99804739190817
# 220.5477 71.4915 220.5306306268206 71.42192655947734
# 245.68646 60.64717 245.69227728197214 60.57671521709358
# 251.07057 52.12906 251.08225831820658 52.05578789690458
# 268.4373 39.16298 268.4549427241133 39.084375155326576
# 288.10298 32.21787 288.12400998991313 32.12860279184283
# 303.49715 69.00245 303.52157228983265 68.93515178552443
# 314.15644 57.86549 314.18311182524616 57.79299636119218
# 328.92215 49.7832 328.95057335845 49.70519655573056
# 348.3962 42.70602 348.4246245159545 42.621364885576334
# 357.35227 29.20945 357.37801031980393 29.104373037972998
# 17.10277 65.94101 17.13955336435538 65.86004902934987
# 30.67863 55.25695 30.709685648998743 55.16992952855003
# 42.39138 48.35846 42.41921527589801 48.266509215609894
# 79.15311 73.13593 79.17252572775828 73.04950115262913
# 102.25439 53.20402 102.27029324593212 53.10960388061964
# 116.22286 47.34319 116.23723540770811 47.24697024591379
# 125.39873 46.8412 125.41139990242266 46.745500073001715
# 158.33151 70.79507 158.3152706143536 70.7129965796756
# 161.51983 63.70537 161.51422515713716 63.621229813752024
# 180.31781 62.65368 180.31109739958262 62.57266218069649
# END
# * *
#        coeff       change     value    sigma
#
#   1     AN         +3.999     +4.00    0.375
#   2     AW        +40.337    +40.34    0.367
#   3     IA        +90.094    +90.09    2.001
#   4     IE       +259.255   +259.26    1.844
#   5     CA        -16.891    -16.89    1.184
#   6     TF        -69.417    -69.42    2.611
#   7     PZZ3     +108.328   +108.33   14.295
#   8     PZZ5     -138.378   -138.38   12.568
#   9     HZCZ4     +14.007    +14.01    2.983
#
# Sky RMS =   1.52
# Popn SD =   1.97
#
# PZZ3 and TF cannot reliably be distinguished.
# PZZ5 and TF cannot reliably be distinguished.
# PZZ5 and PZZ3 cannot reliably be distinguished.
# Action was taken to correct ill-conditioning.  The
# current FITTOL tolerance is 0.01, which exceeds
# the value 0.0019 encountered during the fit.
#
# * * * * *
#
# * END OF SESSION *
#
#
# Pointing model computed successfully.

# %% [markdown]
# ### Other important things to include in the above script are plots of the pointing error in az and ele vs date, the pointing infomation as I did for the other ones, polar plots of the grid and possibly other important points.
